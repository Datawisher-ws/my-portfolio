# %% [markdown]
# # Content

# %% [markdown]
# In the present financial landscape, credit card churn has emerged as a growing concern for banks. With customers increasingly drawn to attractive introductory offers and rewards, they are more likely to switch between credit card providers, impacting banks' profitability and customer retention. The availability of information through digital channels and the ease of comparing offers have empowered consumers to make informed decisions, further contributing to the rising churn rates. To address this challenge, banks must rethink their strategies, offering more personalized and long-term value to retain customers and foster loyalty in this competitive credit card market.

# %%
# load library and import dataset
library(tidyverse)
library(janitor)
df <- read_csv("/kaggle/input/credit-card-customers/BankChurners.csv")
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
#
# Attaching package: ‘janitor’
#
#
# The following objects are masked from ‘package:stats’:
#
#     chisq.test, fisher.test
#
#
# Rows: 10127 Columns: 23
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (6): Attrition_Flag, Gender, Education_Level, Marital_Status, Income_Ca...
# dbl (17): CLIENTNUM, Customer_Age, Dependent_count, Months_on_book, Total_Re...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
# preview data
tibble(df)
colnames(df)

# clean data
df <- clean_names(df)

df %>% 
  is.na() %>% 
  colSums() %>% 
  print()
# Out:
#       CLIENTNUM Attrition_Flag    Customer_Age Gender Dependent_count
# 1     768805383 Existing Customer 45           M      3
# 2     818770008 Existing Customer 49           F      5
# 3     713982108 Existing Customer 51           M      3
# 4     769911858 Existing Customer 40           F      4
# 5     709106358 Existing Customer 40           M      3
# 6     713061558 Existing Customer 44           M      2
# 7     810347208 Existing Customer 51           M      4
# 8     818906208 Existing Customer 32           M      0
# 9     710930508 Existing Customer 37           M      3
# 10    719661558 Existing Customer 48           M      2
# 11    708790833 Existing Customer 42           M      5
# 12    710821833 Existing Customer 65           M      1
# 13    710599683 Existing Customer 56           M      1
# 14    816082233 Existing Customer 35           M      3
# 15    712396908 Existing Customer 57           F      2
# 16    714885258 Existing Customer 44           M      4
# 17    709967358 Existing Customer 48           M      4
# 18    753327333 Existing Customer 41           M      3
# 19    806160108 Existing Customer 61           M      1
# 20    709327383 Existing Customer 45           F      2
# 21    806165208 Existing Customer 47           M      1
# 22    708508758 Attrited Customer 62           F      0
# 23    784725333 Existing Customer 41           M      3
# 24    811604133 Existing Customer 47           F      4
# 25    789124683 Existing Customer 54           M      2
# 26    771071958 Existing Customer 41           F      3
# 27    720466383 Existing Customer 59           M      1
# 28    804424383 Existing Customer 63           M      1
# 29    718813833 Existing Customer 44           F      3
# 30    806624208 Existing Customer 47           M      4
# ⋮     ⋮         ⋮                 ⋮            ⋮      ⋮
# 10098 801036033 Existing Customer 31           M      0
# 10099 716644008 Attrited Customer 55           M      3
# 10100 709094358 Existing Customer 51           F      1
# 10101 719848008 Existing Customer 39           M      2
# 10102 718372458 Existing Customer 42           M      2
# 10103 720608658 Existing Customer 33           F      1
# 10104 717185658 Attrited Customer 51           M      1
# 10105 715474083 Existing Customer 51           M      3
# 10106 709646433 Attrited Customer 59           F      1
# 10107 717494358 Existing Customer 58           F      0
# 10108 713924283 Attrited Customer 61           M      0
# 10109 714471183 Attrited Customer 47           M      4
# 10110 780613758 Existing Customer 47           M      5
# 10111 718225683 Existing Customer 56           M      1
# 10112 710734308 Existing Customer 49           M      1
# 10113 708564858 Attrited Customer 33           M      2
# 10114 713733633 Attrited Customer 27           M      0
# 10115 720841533 Existing Customer 29           M      0
# 10116 712210458 Existing Customer 38           M      1
# 10117 714109308 Existing Customer 46           M      5
# 10118 712503408 Existing Customer 57           M      2
# 10119 713755458 Attrited Customer 50           M      1
# 10120 716893683 Attrited Customer 55           F      3
# 10121 710841183 Existing Customer 54           M      1
# 10122 713899383 Existing Customer 56           F      1
# 10123 772366833 Existing Customer 50           M      2
# 10124 710638233 Attrited Customer 41           M      2
# 10125 716506083 Attrited Customer 44           F      1
# 10126 717406983 Attrited Customer 30           M      2
# 10127 714337233 Attrited Customer 43           F      2
#       Education_Level Marital_Status Income_Category Card_Category
# 1     High School     Married        $60K - $80K     Blue
# 2     Graduate        Single         Less than $40K  Blue
# 3     Graduate        Married        $80K - $120K    Blue
# 4     High School     Unknown        Less than $40K  Blue
# 5     Uneducated      Married        $60K - $80K     Blue
# 6     Graduate        Married        $40K - $60K     Blue
# 7     Unknown         Married        $120K +         Gold
# 8     High School     Unknown        $60K - $80K     Silver
# 9     Uneducated      Single         $60K - $80K     Blue
# 10    Graduate        Single         $80K - $120K    Blue
# 11    Uneducated      Unknown        $120K +         Blue
# 12    Unknown         Married        $40K - $60K     Blue
# 13    College         Single         $80K - $120K    Blue
# 14    Graduate        Unknown        $60K - $80K     Blue
# 15    Graduate        Married        Less than $40K  Blue
# 16    Unknown         Unknown        $80K - $120K    Blue
# 17    Post-Graduate   Single         $80K - $120K    Blue
# 18    Unknown         Married        $80K - $120K    Blue
# 19    High School     Married        $40K - $60K     Blue
# 20    Graduate        Married        Unknown         Blue
# 21    Doctorate       Divorced       $60K - $80K     Blue
# 22    Graduate        Married        Less than $40K  Blue
# 23    High School     Married        $40K - $60K     Blue
# 24    Unknown         Single         Less than $40K  Blue
# 25    Unknown         Married        $80K - $120K    Blue
# 26    Graduate        Single         Less than $40K  Blue
# 27    High School     Unknown        $40K - $60K     Blue
# 28    Unknown         Married        $60K - $80K     Blue
# 29    Uneducated      Single         Unknown         Blue
# 30    High School     Married        $40K - $60K     Blue
# ⋮     ⋮               ⋮              ⋮               ⋮
# 10098 High School     Single         $40K - $60K     Blue
# 10099 Graduate        Single         $120K +         Silver
# 10100 Graduate        Single         Less than $40K  Blue
# 10101 Graduate        Unknown        $60K - $80K     Silver
# 10102 Graduate        Unknown        $40K - $60K     Blue
# 10103 Uneducated      Single         Less than $40K  Blue
# 10104 High School     Married        $80K - $120K    Blue
# 10105 Graduate        Single         $60K - $80K     Silver
# 10106 High School     Married        Less than $40K  Blue
# 10107 Graduate        Single         Less than $40K  Blue
# 10108 Graduate        Single         $60K - $80K     Blue
# 10109 Graduate        Divorced       $80K - $120K    Blue
# 10110 High School     Single         Less than $40K  Blue
# 10111 Graduate        Single         $80K - $120K    Silver
# 10112 Graduate        Single         $60K - $80K     Blue
# 10113 College         Married        $120K +         Gold
# 10114 High School     Divorced       $60K - $80K     Blue
# 10115 Graduate        Married        Less than $40K  Blue
# 10116 Uneducated      Single         $40K - $60K     Blue
# 10117 College         Single         $80K - $120K    Blue
# 10118 Graduate        Married        $80K - $120K    Blue
# 10119 Unknown         Unknown        $80K - $120K    Blue
# 10120 Uneducated      Single         Unknown         Blue
# 10121 High School     Single         $60K - $80K     Blue
# 10122 Graduate        Single         Less than $40K  Blue
# 10123 Graduate        Single         $40K - $60K     Blue
# 10124 Unknown         Divorced       $40K - $60K     Blue
# 10125 High School     Married        Less than $40K  Blue
# 10126 Graduate        Unknown        $40K - $60K     Blue
# 10127 Graduate        Married        Less than $40K  Silver
#       Months_on_book ⋯ Credit_Limit Total_Revolving_Bal Avg_Open_To_Buy
# 1     39             ⋯ 12691.0       777                11914.0
# 2     44             ⋯  8256.0       864                 7392.0
# 3     36             ⋯  3418.0         0                 3418.0
# 4     34             ⋯  3313.0      2517                  796.0
# 5     21             ⋯  4716.0         0                 4716.0
# 6     36             ⋯  4010.0      1247                 2763.0
# 7     46             ⋯ 34516.0      2264                32252.0
# 8     27             ⋯ 29081.0      1396                27685.0
# 9     36             ⋯ 22352.0      2517                19835.0
# 10    36             ⋯ 11656.0      1677                 9979.0
# 11    31             ⋯  6748.0      1467                 5281.0
# 12    54             ⋯  9095.0      1587                 7508.0
# 13    36             ⋯ 11751.0         0                11751.0
# 14    30             ⋯  8547.0      1666                 6881.0
# 15    48             ⋯  2436.0       680                 1756.0
# 16    37             ⋯  4234.0       972                 3262.0
# 17    36             ⋯ 30367.0      2362                28005.0
# 18    34             ⋯ 13535.0      1291                12244.0
# 19    56             ⋯  3193.0      2517                  676.0
# 20    37             ⋯ 14470.0      1157                13313.0
# 21    42             ⋯ 20979.0      1800                19179.0
# 22    49             ⋯  1438.3         0                 1438.3
# 23    33             ⋯  4470.0       680                 3790.0
# 24    36             ⋯  2492.0      1560                  932.0
# 25    42             ⋯ 12217.0         0                12217.0
# 26    28             ⋯  7768.0      1669                 6099.0
# 27    46             ⋯ 14784.0      1374                13410.0
# 28    56             ⋯ 10215.0      1010                 9205.0
# 29    34             ⋯ 10100.0         0                10100.0
# 30    42             ⋯  4785.0      1362                 3423.0
# ⋮     ⋮              ⋱ ⋮            ⋮                   ⋮
# 10098 25             ⋯  4493        1388                 3105
# 10099 36             ⋯ 34516           0                34516
# 10100 41             ⋯  8900         798                 8102
# 10101 36             ⋯ 29808           0                29808
# 10102 30             ⋯  3735        1723                 2012
# 10103 36             ⋯  8398        1875                 6523
# 10104 36             ⋯ 22754           0                22754
# 10105 36             ⋯ 29663        1743                27920
# 10106 50             ⋯  5043         743                 4300
# 10107 48             ⋯  4299        1334                 2965
# 10108 54             ⋯ 11859        1644                10215
# 10109 39             ⋯ 17504         476                17028
# 10110 35             ⋯  4165           0                 4165
# 10111 49             ⋯ 34516        1091                33425
# 10112 40             ⋯  6481        1569                 4912
# 10113 20             ⋯ 34516           0                34516
# 10114 36             ⋯ 13303        2517                10786
# 10115 15             ⋯  4700           0                 4700
# 10116 36             ⋯  5639        1558                 4081
# 10117 36             ⋯ 13187        2241                10946
# 10118 40             ⋯ 17925        1909                16016
# 10119 36             ⋯  9959         952                 9007
# 10120 47             ⋯ 14657        2517                12140
# 10121 34             ⋯ 13940        2109                11831
# 10122 50             ⋯  3688         606                 3082
# 10123 40             ⋯  4003        1851                 2152
# 10124 25             ⋯  4277        2186                 2091
# 10125 36             ⋯  5409           0                 5409
# 10126 36             ⋯  5281           0                 5281
# 10127 25             ⋯ 10388        1961                 8427
#       Total_Amt_Chng_Q4_Q1 Total_Trans_Amt Total_Trans_Ct Total_Ct_Chng_Q4_Q1
# 1     1.335                1144            42             1.625
# 2     1.541                1291            33             3.714
# 3     2.594                1887            20             2.333
# 4     1.405                1171            20             2.333
# 5     2.175                 816            28             2.500
# 6     1.376                1088            24             0.846
# 7     1.975                1330            31             0.722
# 8     2.204                1538            36             0.714
# 9     3.355                1350            24             1.182
# 10    1.524                1441            32             0.882
# 11    0.831                1201            42             0.680
# 12    1.433                1314            26             1.364
# 13    3.397                1539            17             3.250
# 14    1.163                1311            33             2.000
# 15    1.190                1570            29             0.611
# 16    1.707                1348            27             1.700
# 17    1.708                1671            27             0.929
# 18    0.653                1028            21             1.625
# 19    1.831                1336            30             1.143
# 20    0.966                1207            21             0.909
# 21    0.906                1178            27             0.929
# 22    1.047                 692            16             0.600
# 23    1.608                 931            18             1.571
# 24    0.573                1126            23             0.353
# 25    1.075                1110            21             0.750
# 26    0.797                1051            22             0.833
# 27    0.921                1197            23             1.300
# 28    0.843                1904            40             1.000
# 29    0.525                1052            18             1.571
# 30    0.739                1045            38             0.900
# ⋮     ⋮                    ⋮               ⋮              ⋮
# 10098 0.795                17744           104            0.763
# 10099 1.007                 9931            70            0.750
# 10100 0.647                16737            88            0.660
# 10101 0.669                16098           128            0.684
# 10102 0.595                14501            92            0.840
# 10103 0.727                16706           123            0.757
# 10104 0.799                 8531            77            0.791
# 10105 0.667                14638            93            0.722
# 10106 0.805                10170            66            0.784
# 10107 0.660                15068           123            0.685
# 10108 0.866                 8930            79            0.837
# 10109 0.892                10468            66            0.737
# 10110 0.813                17093           111            0.820
# 10111 0.640                15274           108            0.714
# 10112 0.692                15937           119            0.803
# 10113 1.004                 9338            73            0.622
# 10114 0.929                10219            85            0.809
# 10115 0.617                14723            96            0.655
# 10116 0.614                16628           109            0.946
# 10117 0.689                15354           112            0.931
# 10118 0.712                17498           111            0.820
# 10119 0.825                10310            63            1.100
# 10120 0.166                 6009            53            0.514
# 10121 0.660                15577           114            0.754
# 10122 0.570                14596           120            0.791
# 10123 0.703                15476           117            0.857
# 10124 0.804                 8764            69            0.683
# 10125 0.819                10291            60            0.818
# 10126 0.535                 8395            62            0.722
# 10127 0.703                10294            61            0.649
#       Avg_Utilization_Ratio
# 1     0.061
# 2     0.105
# 3     0.000
# 4     0.760
# 5     0.000
# 6     0.311
# 7     0.066
# 8     0.048
# 9     0.113
# 10    0.144
# 11    0.217
# 12    0.174
# 13    0.000
# 14    0.195
# 15    0.279
# 16    0.230
# 17    0.078
# 18    0.095
# 19    0.788
# 20    0.080
# 21    0.086
# 22    0.000
# 23    0.152
# 24    0.626
# 25    0.000
# 26    0.215
# 27    0.093
# 28    0.099
# 29    0.000
# 30    0.285
# ⋮     ⋮
# 10098 0.309
# 10099 0.000
# 10100 0.090
# 10101 0.000
# 10102 0.461
# 10103 0.223
# 10104 0.000
# 10105 0.059
# 10106 0.147
# 10107 0.310
# 10108 0.139
# 10109 0.027
# 10110 0.000
# 10111 0.032
# 10112 0.242
# 10113 0.000
# 10114 0.189
# 10115 0.000
# 10116 0.276
# 10117 0.170
# 10118 0.106
# 10119 0.096
# 10120 0.172
# 10121 0.151
# 10122 0.164
# 10123 0.462
# 10124 0.511
# 10125 0.000
# 10126 0.000
# 10127 0.189
#       Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1
# 1     9.3448e-05
# 2     5.6861e-05
# 3     2.1081e-05
# 4     1.3366e-04
# 5     2.1676e-05
# 6     5.5077e-05
# 7     1.2303e-04
# 8     8.5795e-05
# 9     4.4796e-05
# 10    3.0251e-04
# 11    1.9094e-04
# 12    1.9751e-04
# 13    4.7799e-05
# 14    9.6126e-05
# 15    1.1382e-04
# 16    6.3492e-05
# 17    2.3623e-04
# 18    1.4953e-04
# 19    1.7468e-04
# 20    5.5077e-05
# 21    5.7030e-05
# 22    9.9616e-01
# 23    6.9242e-05
# 24    2.0735e-04
# 25    2.1042e-04
# 26    5.7151e-05
# 27    5.0256e-05
# 28    1.8558e-04
# 29    1.2144e-04
# 30    7.6642e-06
# ⋮     ⋮
# 10098 1.5970e-04
# 10099 9.9794e-01
# 10100 1.7969e-04
# 10101 1.0284e-04
# 10102 5.6498e-04
# 10103 2.9196e-04
# 10104 9.9788e-01
# 10105 1.0672e-04
# 10106 9.9701e-01
# 10107 4.8486e-04
# 10108 9.9268e-01
# 10109 9.9816e-01
# 10110 8.9586e-04
# 10111 9.6533e-05
# 10112 2.8395e-04
# 10113 9.9438e-01
# 10114 9.9338e-01
# 10115 2.3467e-04
# 10116 1.7360e-04
# 10117 1.9215e-04
# 10118 5.1600e-04
# 10119 9.9813e-01
# 10120 9.9691e-01
# 10121 3.8311e-05
# 10122 1.4834e-04
# 10123 1.9143e-04
# 10124 9.9527e-01
# 10125 9.9788e-01
# 10126 9.9671e-01
# 10127 9.9662e-01
#       Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2
# 1     0.9999100
# 2     0.9999400
# 3     0.9999800
# 4     0.9998700
# 5     0.9999800
# 6     0.9999400
# 7     0.9998800
# 8     0.9999100
# 9     0.9999600
# 10    0.9997000
# 11    0.9998100
# 12    0.9998000
# 13    0.9999500
# 14    0.9999000
# 15    0.9998900
# 16    0.9999400
# 17    0.9997600
# 18    0.9998500
# 19    0.9998300
# 20    0.9999400
# 21    0.9999400
# 22    0.0038363
# 23    0.9999300
# 24    0.9997900
# 25    0.9997900
# 26    0.9999400
# 27    0.9999500
# 28    0.9998100
# 29    0.9998800
# 30    0.9999900
# ⋮     ⋮
# 10098 0.99984000
# 10099 0.00206163
# 10100 0.99982000
# 10101 0.99990000
# 10102 0.99944000
# 10103 0.99971000
# 10104 0.00211827
# 10105 0.99989000
# 10106 0.00298772
# 10107 0.99952000
# 10108 0.00732000
# 10109 0.00184351
# 10110 0.99910000
# 10111 0.99990000
# 10112 0.99972000
# 10113 0.00562000
# 10114 0.00662000
# 10115 0.99977000
# 10116 0.99983000
# 10117 0.99981000
# 10118 0.99948000
# 10119 0.00187387
# 10120 0.00308778
# 10121 0.99996000
# 10122 0.99985000
# 10123 0.99981000
# 10124 0.00472896
# 10125 0.00211827
# 10126 0.00329379
# 10127 0.00337654
#  [1] "CLIENTNUM"
#  [2] "Attrition_Flag"
#  [3] "Customer_Age"
#  [4] "Gender"
#  [5] "Dependent_count"
#  [6] "Education_Level"
#  [7] "Marital_Status"
#  [8] "Income_Category"
#  [9] "Card_Category"
# [10] "Months_on_book"
# [11] "Total_Relationship_Count"
# [12] "Months_Inactive_12_mon"
# [13] "Contacts_Count_12_mon"
# [14] "Credit_Limit"
# [15] "Total_Revolving_Bal"
# [16] "Avg_Open_To_Buy"
# [17] "Total_Amt_Chng_Q4_Q1"
# [18] "Total_Trans_Amt"
# [19] "Total_Trans_Ct"
# [20] "Total_Ct_Chng_Q4_Q1"
# [21] "Avg_Utilization_Ratio"
# [22] "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1"
# [23] "Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2"
#                                                                                                                          clientnum
#                                                                                                                                  0
#                                                                                                                     attrition_flag
#                                                                                                                                  0
#                                                                                                                       customer_age
#                                                                                                                                  0
#                                                                                                                             gender
#                                                                                                                                  0
#                                                                                                                    dependent_count
#                                                                                                                                  0
#                                                                                                                    education_level
#                                                                                                                                  0
#                                                                                                                     marital_status
#                                                                                                                                  0
#                                                                                                                    income_category
#                                                                                                                                  0
#                                                                                                                      card_category
#                                                                                                                                  0
#                                                                                                                     months_on_book
#                                                                                                                                  0
#                                                                                                           total_relationship_count
#                                                                                                                                  0
#                                                                                                             months_inactive_12_mon
#                                                                                                                                  0
#                                                                                                              contacts_count_12_mon
#                                                                                                                                  0
#                                                                                                                       credit_limit
#                                                                                                                                  0
#                                                                                                                total_revolving_bal
#                                                                                                                                  0
#                                                                                                                    avg_open_to_buy
#                                                                                                                                  0
#                                                                                                               total_amt_chng_q4_q1
#                                                                                                                                  0
#                                                                                                                    total_trans_amt
#                                                                                                                                  0
#                                                                                                                     total_trans_ct
#                                                                                                                                  0
#                                                                                                                total_ct_chng_q4_q1
#                                                                                                                                  0
#                                                                                                              avg_utilization_ratio
#                                                                                                                                  0
# naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_1
#                                                                                                                                  0
# naive_bayes_classifier_attrition_flag_card_category_contacts_count_12_mon_dependent_count_education_level_months_inactive_12_mon_2
#                                                                                                                                  0

# %% [markdown]
# # Data manipulation

# %%
# change format
df$gender <- ifelse(df$gender == "M", "Male", "Female")

# create age groups
breaks <- c(0, 41, 51, Inf)

age_labels <- c("0-40", "41-50", "over 50")
age_group <- cut(df$customer_age, breaks = breaks, labels = age_labels)

df["age_group"] <- age_group

# %% [markdown]
# # Data exploration

# %% [markdown]
# Despite a 16% of attrited customer is not high rate, but the bank is deeply concerned about customer churn and understands the potential impact on its business. To address this, the bank aims to improve its services and focus on customer retention.

# %%
# to find most customer amount in each category
df %>% 
  select(attrition_flag) %>% 
  group_by(attrition_flag) %>% 
  summarise(count = n())

atttrition_perc <- (1627/(1627+8500))*100

atttrition_perc
# Out:
#   attrition_flag    count
# 1 Attrited Customer 1627
# 2 Existing Customer 8500
# [1] 16.06596

# %% [markdown]
# ![Sheet 1.png](attachment:81e75dee-5663-4aec-9a51-04723b5ce658.png)

# %%
df %>% 
  select(gender) %>% 
  group_by(gender) %>% 
  summarise(count = n()) %>%
  arrange(desc(count))

income_preview <- df %>% 
  select(income_category) %>% 
  group_by(income_category) %>% 
  summarise( count = n()) %>% 
  arrange(desc(income_category))

income_preview

df %>% 
  select(age_group) %>% 
  group_by(age_group) %>% 
  summarise(count = n()) %>%
  arrange(desc(count))

df %>% 
  select(card_category) %>% 
  group_by(card_category) %>% 
  summarise( count = n()) %>%
  arrange(desc(count))

df %>% 
  select(education_level) %>% 
  group_by(education_level) %>% 
  summarise( count = n()) %>%
  arrange(desc(count))
# Out:
#   gender count
# 1 Female 5358
# 2 Male   4769
#   income_category count
# 1 Unknown         1112
# 2 Less than $40K  3561
# 3 $80K - $120K    1535
# 4 $60K - $80K     1402
# 5 $40K - $60K     1790
# 6 $120K +          727
#   age_group count
# 1 41-50     4671
# 2 0-40      2776
# 3 over 50   2680
#   card_category count
# 1 Blue          9436
# 2 Silver         555
# 3 Gold           116
# 4 Platinum        20
#   education_level count
# 1 Graduate        3128
# 2 High School     2013
# 3 Unknown         1519
# 4 Uneducated      1487
# 5 College         1013
# 6 Post-Graduate    516
# 7 Doctorate        451

# %% [markdown]
# # Data analysis

# %%
# Attrited Customer in each card category
card_group <- df %>% 
  select(card_category, attrition_flag) %>%
  filter(attrition_flag == 'Attrited Customer') %>% 
  group_by(card_category) %>% 
  summarise(count = n()) %>% 
  arrange(desc(count))

# Attrited Customer in each gender 
gender_group <- df %>% 
  select(gender, attrition_flag) %>% 
  filter(attrition_flag == 'Attrited Customer') %>% 
  group_by(gender) %>% 
  summarise(count = n()) %>% 
  arrange(desc(count))

# Attrited Customer in each education level
educate_group <- df %>% 
  select(education_level, attrition_flag) %>% 
  filter(attrition_flag == 'Attrited Customer') %>% 
  group_by(education_level) %>%
  summarise(count = n()) %>% 
  arrange(desc(count))

# %% [markdown]
# We have income range for our customer and top high attrited customer percent range is 120K but this group is a few customer in our bank so, we will focus on no.2 is less income than 40K which is the most our customer.

# %%
# Attrited Customer in each income category
income_group <- df %>% 
  select(income_category, attrition_flag) %>% 
  filter(attrition_flag == 'Attrited Customer') %>% 
  group_by(income_category) %>% 
  summarise(count = n()) %>% 
  arrange(desc(income_category))

income_cal <- (income_group$count/income_preview$count)*100

income_cal <- data.frame(income_preview, income_group, income_cal)

income_cal %>% rename(actual_income=income_category, attrition_income=income_category.1, percent_change=income_cal) %>% arrange(desc(percent_change))
# Out:
#   actual_income  count attrition_income count.1 percent_change
# 1 $120K +         727  $120K +          126     17.33150
# 2 Less than $40K 3561  Less than $40K   612     17.18618
# 3 Unknown        1112  Unknown          187     16.81655
# 4 $80K - $120K   1535  $80K - $120K     242     15.76547
# 5 $40K - $60K    1790  $40K - $60K      271     15.13966
# 6 $60K - $80K    1402  $60K - $80K      189     13.48074

# %% [markdown]
# ![Sheet 2.png](attachment:76916085-69a4-44c0-8bd0-4a1a122f507b.png)

# %%
# correlationship between income, age, gender and attrited customer
df$attrition_flag <-  as.numeric(ifelse(df$attrition_flag == "Attrited Customer", 1, 0))

# %%
df$gender <- as.numeric(ifelse(df$gender == "Female", 1 , 0))

# %%
df %>% 
  select(months_inactive_12_mon, credit_limit, customer_age, gender, attrition_flag) %>% 
  cor()
# Out:
#                        months_inactive_12_mon credit_limit customer_age
# months_inactive_12_mon  1.00000000            -0.020393791 0.054360999
# credit_limit           -0.02039379             1.000000000 0.002476227
# customer_age            0.05436100             0.002476227 1.000000000
# gender                  0.01116330            -0.420806270 0.017311520
# attrition_flag          0.15244881            -0.023872995 0.018203139
#                        gender      attrition_flag
# months_inactive_12_mon  0.01116330  0.15244881
# credit_limit           -0.42080627 -0.02387299
# customer_age            0.01731152  0.01820314
# gender                  1.00000000  0.03727170
# attrition_flag          0.03727170  1.00000000

# %% [markdown]
# ![Sheet 4.png](attachment:61a8bfd1-6245-4da1-ae13-272faaf37ea4.png)

# %% [markdown]
# Months Inactive in 12 month is kindly close to one more than other factor, so it can summarise to attrition customer and Months Inactive in 12 month have relationship more than credit limit, customer age and gender.
